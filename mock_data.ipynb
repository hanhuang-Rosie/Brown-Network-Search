# %%
import pandas as pd

# 1. Mock Manager / Targeted Person Data
manager_df = pd.DataFrame([
    {
        "targeted person": "Omar Rahman",
        "education_1_school": "Georgetown University",
        "education_1_grad_year": "2008",
        "education_2_school": "",
        "education_2_grad_year": "",
        "current_company": "Access Holdings",
        "current_title": "CFO",
        "current_start_year": "2017",
        "prior_company_1": "EJF Capital",
        "prior_title_1": "Director",
        "prior_start_year_1": "2012",
        "prior_end_year_1": "2017",
        "prior_company_2": "",
        "prior_title_2": "",
        "prior_start_year_2": "",
        "prior_end_year_2": "",
        "industry_focus": "Private Equity; Fund Operations",
        "geography": "US",
        "brown_related_flag": "Yes",
        "source_url": "https://www.accessholdings.com/",
        "source_type": "Sponsor list + public bio",
        "notes": "Also appears in IO contact list; company overlaps with Brown alumni employer."
    },
    {
        "targeted person": "Katie Leshinsky",
        "education_1_school": "Dickinson College",
        "education_1_grad_year": "2014",
        "education_2_school": "",
        "education_2_grad_year": "",
        "current_company": "DFW Capital Partners",
        "current_title": "Director of Investor Relations",
        "current_start_year": "2024",
        "prior_company_1": "Access Holdings",
        "prior_title_1": "Associate Director",
        "prior_start_year_1": "2018",
        "prior_end_year_1": "2024",
        "prior_company_2": "",
        "prior_title_2": "",
        "prior_start_year_2": "",
        "prior_end_year_2": "",
        "industry_focus": "Private Equity; Investor Relations; ESG",
        "geography": "US",
        "brown_related_flag": "Yes",
        "source_url": "https://www.dfwcapital.com/",
        "source_type": "Public bio + LinkedIn manual verification",
        "notes": "Appears in IO contact list; prior company overlaps with Brown alumni employer."
    },
    {
        "targeted person": "Kim Kile",
        "education_1_school": "Bloomsburg University",
        "education_1_grad_year": "2000",
        "education_2_school": "University of Baltimore",
        "education_2_grad_year": "2005",
        "current_company": "Victor Capital Partners",
        "current_title": "Senior Advisor",
        "current_start_year": "2025",
        "prior_company_1": "Access Holdings",
        "prior_title_1": "Managing Director",
        "prior_start_year_1": "2017",
        "prior_end_year_1": "2025",
        "prior_company_2": "ABS Capital Partners",
        "prior_title_2": "General Partner",
        "prior_start_year_2": "1999",
        "prior_end_year_2": "2017",
        "industry_focus": "Private Equity; Fundraising; Investor Relations",
        "geography": "US",
        "brown_related_flag": "Yes",
        "source_url": "https://www.victorcapitalpartners.com/",
        "source_type": "Public bio",
        "notes": "Current company overlaps with Brown alumni employer."
    },
    {
        "targeted person": "Heather Meeder",
        "education_1_school": "Dickinson College",
        "education_1_grad_year": "2019",
        "education_2_school": "",
        "education_2_grad_year": "",
        "current_company": "EFESO / Maine Pointe",
        "current_title": "Director of Strategy and Business Development",
        "current_start_year": "2025",
        "prior_company_1": "Access Holdings",
        "prior_title_1": "Senior Business Development Analyst",
        "prior_start_year_1": "2020",
        "prior_end_year_1": "2024",
        "prior_company_2": "",
        "prior_title_2": "",
        "prior_start_year_2": "",
        "prior_end_year_2": "",
        "industry_focus": "Private Equity; Business Development; Strategy",
        "geography": "US",
        "brown_related_flag": "No",
        "source_url": "https://www.efeso.com/",
        "source_type": "Public bio",
        "notes": "No direct Brown connection identified in mock data."
    }
])


# 2. Mock Alumni Data
alumni_df = pd.DataFrame([
    {
        "Managed": "Yes",
        "Constituency": "Alumnus/a: Undergraduate",
        "Unique Identifier": "A001",
        "First Name": "John",
        "Middle Name": "",
        "Last Name": "Smith",
        "Personal Suffix": "",
        "Professional Suffix": "",
        "Primary Employer": "Access Holdings",
        "Job Title": "Partner",
        "Field of Work": "Investment Management",
        "Field of Specialty 1": "Private Equity",
        "Field of Specialty 2": "Healthcare",
        "Field of Specialty 3": "",
        "Full Name": "John Smith"
    },
    {
        "Managed": "No",
        "Constituency": "Alumnus/a: Graduate",
        "Unique Identifier": "A002",
        "First Name": "Emily",
        "Middle Name": "",
        "Last Name": "Chen",
        "Personal Suffix": "",
        "Professional Suffix": "",
        "Primary Employer": "DFW Capital Partners",
        "Job Title": "Vice President",
        "Field of Work": "Finance",
        "Field of Specialty 1": "Investor Relations",
        "Field of Specialty 2": "Private Equity",
        "Field of Specialty 3": "Fundraising",
        "Full Name": "Emily Chen"
    },
    {
        "Managed": "Yes",
        "Constituency": "Alumnus/a: Undergraduate",
        "Unique Identifier": "A003",
        "First Name": "Michael",
        "Middle Name": "",
        "Last Name": "Lee",
        "Personal Suffix": "",
        "Professional Suffix": "",
        "Primary Employer": "Victor Capital Partners",
        "Job Title": "Principal",
        "Field of Work": "Investment Management",
        "Field of Specialty 1": "Consumer",
        "Field of Specialty 2": "Industrial Services",
        "Field of Specialty 3": "Private Equity",
        "Full Name": "Michael Lee"
    },
    {
        "Managed": "No",
        "Constituency": "Alumnus/a: Medical",
        "Unique Identifier": "A004",
        "First Name": "Sarah",
        "Middle Name": "A.",
        "Last Name": "Johnson",
        "Personal Suffix": "",
        "Professional Suffix": "MD",
        "Primary Employer": "Healthcare Growth Partners",
        "Job Title": "Advisor",
        "Field of Work": "Healthcare",
        "Field of Specialty 1": "Biotech",
        "Field of Specialty 2": "Venture Capital",
        "Field of Specialty 3": "",
        "Full Name": "Sarah A. Johnson"
    }
])

# 3. Mock IO Contacts Data
io_contacts_df = pd.DataFrame([
    {
        "First Name": "Omar",
        "Last Name": "Rahman",
        "URL": "https://www.linkedin.com/in/omar-r-7928841",
        "Email Address": "",
        "Company": "Access Holdings",
        "Position": "CFO",
        "Connected On": "2021-05-10",
        "Contact Full Name": "Omar Rahman",
        "IO Member": "Julien Angel",
        "Source Type": "LinkedIn contact export"
    },
    {
        "First Name": "Katie",
        "Last Name": "Leshinsky",
        "URL": "https://www.linkedin.com/in/katie-leshinsky",
        "Email Address": "",
        "Company": "DFW Capital Partners",
        "Position": "Director of Investor Relations",
        "Connected On": "2022-07-18",
        "Contact Full Name": "Katie Leshinsky",
        "IO Member": "IO Member 2",
        "Source Type": "LinkedIn contact export"
    },
    {
        "First Name": "Jane",
        "Last Name": "Brown",
        "URL": "https://www.linkedin.com/in/jane-brown",
        "Email Address": "",
        "Company": "Access Holdings",
        "Position": "Vice President",
        "Connected On": "2020-03-15",
        "Contact Full Name": "Jane Brown",
        "IO Member": "Julien Angel",
        "Source Type": "LinkedIn contact export"
    },
    {
        "First Name": "Michael",
        "Last Name": "Lee",
        "URL": "https://www.linkedin.com/in/michael-lee",
        "Email Address": "",
        "Company": "Victor Capital Partners",
        "Position": "Principal",
        "Connected On": "2019-11-02",
        "Contact Full Name": "Michael Lee",
        "IO Member": "IO Member 3",
        "Source Type": "LinkedIn contact export"
    }
])


print("Manager DataFrame:")
print(manager_df)

print("\nAlumni DataFrame:")
print(alumni_df)

print("\nIO Contacts DataFrame:")
print(io_contacts_df)


manager_df.to_csv("mock_managers.csv", index=False)
alumni_df.to_csv("mock_alumni.csv", index=False)
io_contacts_df.to_csv("mock_io_contacts.csv", index=False)
# Out:
# Manager DataFrame:
#    targeted person     education_1_school education_1_grad_year  \
# 0      Omar Rahman  Georgetown University                  2008
# 1  Katie Leshinsky      Dickinson College                  2014
# 2         Kim Kile  Bloomsburg University                  2000
# 3   Heather Meeder      Dickinson College                  2019
#
#         education_2_school education_2_grad_year          current_company  \
# 0                                                         Access Holdings
# 1                                                    DFW Capital Partners
# 2  University of Baltimore                  2005  Victor Capital Partners
# 3                                                    EFESO / Maine Pointe
#
#                                    current_title current_start_year  \
# 0                                            CFO               2017
# 1                 Director of Investor Relations               2024
# ...
